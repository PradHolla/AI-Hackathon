# %%
import boto3
import base64
import json
from pathlib import Path
from langchain_aws import ChatBedrock
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder, SystemMessagePromptTemplate

# %%
# Initialize the Textract client
textract = boto3.client('textract')

llm = ChatBedrock(model="us.meta.llama3-2-90b-instruct-v1:0")

# %%
# Read the local file
with open('myopd-sample-rx-eng.png', 'rb') as file:
    image_bytes = file.read()

# Call Textract API
response = textract.detect_document_text(
    Document={'Bytes': image_bytes}
    )

# Print the response
print(json.dumps(response, indent=4))
# Out:
# {
#     "DocumentMetadata": {
#         "Pages": 1
#     },
#     "Blocks": [
#         {
#             "BlockType": "PAGE",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 1.0,
#                     "Height": 1.0,
#                     "Left": 0.0,
#                     "Top": 0.0
#                 },
#                 "Polygon": [
#                     {
#                         "X": 5.674030489899451e-07,
#                         "Y": 0.0
#                     },
#                     {
#                         "X": 1.0,
#                         "Y": 2.09909671866626e-06
#                     },
#                     {
#                         "X": 1.0,
#                         "Y": 1.0
#                     },
#                     {
#                         "X": 0.0,
#                         "Y": 1.0
#                     }
#                 ]
#             },
#             "Id": "856ea651-0f63-4ebf-96bd-0cb61f8343bb",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "ad3f440c-dee2-4ad6-8e4e-c1d0d3cc498b",
#                         "1a71395f-7569-4207-88b8-fcef231c544b",
#                         "755d3129-ccac-4c38-a3ce-2883dcb0e0d9",
#                         "cdb3f976-2d77-435d-8445-53cb54ab99a8",
#                         "9cd6870e-557b-41a6-9969-de8dd84db0fd",
#                         "e8b607b5-2a21-4b52-8cf8-9f11875e4a5e",
#                         "b668ca52-933b-4591-b9be-3238ed7f74e7",
#                         "f45e47a5-1872-42de-af90-6e4588509645",
#                         "e5587060-4cc6-4d41-8dc7-04926b3a37c1",
#                         "ecde0450-b66f-4087-b2c6-2ea25c137ad0",
#                         "86ac360d-04bb-4fd8-b89f-731d6dd567cb",
#                         "74e53db9-0344-499f-a314-4d3812c455c9",
#                         "74793fdd-e8ec-49c4-b7bd-764d30ad03bf",
#                         "3bc9046f-3105-4716-9572-9fbb40e9e15f",
#                         "aae2ce35-6bab-441f-b3c3-21debb47fd27",
#                         "d6c61381-5cf8-418b-8343-75271a772b02",
#                         "8a4f47d5-cffa-470c-b6ed-d27d44af0213",
#                         "5fbe8e1b-13ef-449c-81aa-39f2b49ff8e7",
#                         "bee4c1d2-760e-4c21-8571-b3bb0186eaae",
#                         "274f4af7-d81a-42d8-b810-dd0f090bf831",
#                         "03e68db1-a052-43bc-b50c-e4c1a950e256",
#                         "8e12c118-760e-48ea-8fb9-9e9d33135e48",
#                         "25a85fea-210c-49df-821f-8bb5cdc0095f",
#                         "3a5a0940-b3c7-419c-8f33-e4b43aa10100",
#                         "24ee955d-1c71-432f-a776-e0b00374c60f",
#                         "cf009801-5e3d-481a-aa85-1c00042286a7",
#                         "67614576-c85a-40e9-b0aa-c871821f05f8",
#                         "94296689-3fe3-4d0f-a322-071bf5ac164b",
#                         "d1d4752c-005f-42bc-86e1-58021d8df6f6",
#                         "e3cf6484-1d93-4d8a-99d2-4065f1516338",
#                         "00d5b366-930b-47b2-a241-9ec763bd939c",
#                         "f7bb37f1-5b5c-46ff-8382-dd7a45ad511e",
#                         "94164118-f927-46a4-b5f9-78684ba8306a",
#                         "32e939cb-bd5b-4306-ba92-b3e1955bfcd3",
#                         "a8315a77-6fdf-4e4f-88ab-f6ae63e15315",
#                         "99007beb-f136-4054-b3a3-97daa79af2f6",
#                         "ebf584d6-ce09-4c9a-9eb3-b847e8ffaa11",
#                         "0f29c35d-d6df-494f-934c-5433c6c0b4f3",
#                         "09a70386-91bf-4d9e-b30c-a8be2ff12ca5",
#                         "098de0f1-b1de-4c9e-82f8-54a31cca3199",
#                         "12492ca5-84cd-4ba3-bf69-38a3ec96edef",
#                         "73e06e0c-7346-4729-af11-da0fac385ab4",
#                         "ca3aa4d6-8988-42d2-9c3a-e6ae490112a8",
#                         "99f38af2-9236-4024-b7d5-33262c93c349",
#                         "58539f87-ecfb-4594-886a-059a76b7e0c4",
#                         "48c77f4c-37e0-4f25-9840-9fda1d4ac787",
#                         "95268c83-eb80-46fc-8a1a-2d3398872d31",
#                         "e3417df5-b483-4982-9c39-4d36ad28248b",
#                         "59b35420-b99d-4b00-84f6-94b104fbdbf2",
#                         "20b08715-897b-4ccb-b8ba-d24e35d80a5a",
#                         "c2627a92-84f1-433c-8d6d-60b15d854e38",
#                         "3b2af84a-a33a-4dcd-a31f-7765957e7522",
#                         "29e6f5c2-461f-4cd1-891c-ee2784b3917a",
#                         "6152c943-1941-478d-8416-4cb9c1c6fe03",
#                         "32c8aa69-0dff-45ab-9a7f-f6ef26a0d027",
#                         "b9375dc2-034a-4805-8aab-bc1203bbfeb1",
#                         "0a96b46b-e992-4e4a-98f1-6f7f834a81b3",
#                         "e12bc588-f0f5-4ecf-ba82-94a9df586f4e",
#                         "f3823d3e-63e0-4c63-b7f7-1d9690949bbd",
#                         "0e75dff2-55d8-4ea8-8ad0-d8129caaaefa",
#                         "8b4b61ef-2466-42b5-b8ba-2fa6cd236938",
#                         "7b525956-3d6a-403d-a5e2-34cdfce8e2b2",
#                         "7071f382-2ffd-4f8d-a5e6-337e83dfb49a",
#                         "a3c53cab-a9ac-430e-8053-368bda08ecfb",
#                         "61ff54e6-f370-481d-a5f5-8de9e5cdba38",
#                         "03cf06cb-5766-4759-ad8c-812962f14784",
#                         "5e594d5f-d0bd-4469-baa5-62bfb328d361",
#                         "7e3b6918-0944-4245-be90-da4a4ab4c9db",
#                         "93d34bd8-c221-46e4-aff0-84f277b849a6",
#                         "cc3a5e19-5e82-4bd5-889c-75fde3e05517",
#                         "7051f2f0-83ff-4546-abc4-b0896ac174de"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.74015045166016,
#             "Text": "Dr. Onkar Bhave",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.17803406715393066,
#                     "Height": 0.017200041562318802,
#                     "Left": 0.04672829061746597,
#                     "Top": 0.004353102762252092
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.046739865094423294,
#                         "Y": 0.004353102762252092
#                     },
#                     {
#                         "X": 0.22476235032081604,
#                         "Y": 0.0045271990820765495
#                     },
#                     {
#                         "X": 0.22475187480449677,
#                         "Y": 0.021553143858909607
#                     },
#                     {
#                         "X": 0.04672829061746597,
#                         "Y": 0.02137701027095318
#                     }
#                 ]
#             },
#             "Id": "ad3f440c-dee2-4ad6-8e4e-c1d0d3cc498b",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "d130dcb6-d19a-4ba6-a8cc-539160f40ad0",
#                         "40704322-1171-4ad4-9737-7ba3fe6ce33b",
#                         "2818fbfa-7a9d-415b-9ee5-79a99ef36448"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.82792663574219,
#             "Text": "Care Clinic",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.11791019141674042,
#                     "Height": 0.016634229570627213,
#                     "Left": 0.5866013765335083,
#                     "Top": 0.004409785382449627
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.5866093635559082,
#                         "Y": 0.004409785382449627
#                     },
#                     {
#                         "X": 0.7045115828514099,
#                         "Y": 0.004525050055235624
#                     },
#                     {
#                         "X": 0.7045042514801025,
#                         "Y": 0.021044014021754265
#                     },
#                     {
#                         "X": 0.5866013765335083,
#                         "Y": 0.020927442237734795
#                     }
#                 ]
#             },
#             "Id": "1a71395f-7569-4207-88b8-fcef231c544b",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "b0dad2e2-f209-43d5-9640-8bae752ff92e",
#                         "09576a62-ff66-4f02-98a2-15e3fa26a477"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 89.23723602294922,
#             "Text": "M.B.B.S., M.D., M.S. I Reg. No: 270988 I",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.33482426404953003,
#                     "Height": 0.021227147430181503,
#                     "Left": 0.04675449803471565,
#                     "Top": 0.02808876521885395
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.04676870256662369,
#                         "Y": 0.02808876521885395
#                     },
#                     {
#                         "X": 0.3815787732601166,
#                         "Y": 0.02842152863740921
#                     },
#                     {
#                         "X": 0.3815670907497406,
#                         "Y": 0.049315910786390305
#                     },
#                     {
#                         "X": 0.04675449803471565,
#                         "Y": 0.048978447914123535
#                     }
#                 ]
#             },
#             "Id": "755d3129-ccac-4c38-a3ce-2883dcb0e0d9",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "f5277862-d300-42c6-a73d-7bde3e7b53a3",
#                         "3061a431-71d0-4b15-94df-64aa00202c5b",
#                         "e7ecc6cb-4dfd-4d05-a8bf-bf74d392afef",
#                         "2d69a959-2e03-4aa7-9a67-5612bb0a5bac",
#                         "3cc5b4c4-db43-47d9-91f9-1c2207800a47",
#                         "85d18ce3-7673-47d5-806d-3a7e1e2ddde8",
#                         "527a1042-ace6-445b-92c1-56c5cf1fafda",
#                         "f84c3a95-30c9-43a4-b640-cc7f44889fcf"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 96.40611267089844,
#             "Text": "Near Axis Bank, Kothrud, Pune -",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.2829030752182007,
#                     "Height": 0.017116567119956017,
#                     "Left": 0.5856127738952637,
#                     "Top": 0.030082833021879196
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.5856209397315979,
#                         "Y": 0.030082833021879196
#                     },
#                     {
#                         "X": 0.8685158491134644,
#                         "Y": 0.030364276841282845
#                     },
#                     {
#                         "X": 0.8685094118118286,
#                         "Y": 0.04719940200448036
#                     },
#                     {
#                         "X": 0.5856127738952637,
#                         "Y": 0.046914760023355484
#                     }
#                 ]
#             },
#             "Id": "cdb3f976-2d77-435d-8445-53cb54ab99a8",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "5d8dc288-8b2d-4c9f-913f-b6673f44d7ab",
#                         "cd919796-0c30-4e94-8c33-15e1d418be93",
#                         "e590832b-4a61-4e82-a2ee-b6d48588f2dc",
#                         "eda636cb-29f4-4b18-a1f8-81015b1f185a",
#                         "b8eb78b6-25d8-4150-9e3f-ad64e7cf8bad",
#                         "081e0b69-7fdb-4793-ba39-17fbc738eabe"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.25137329101562,
#             "Text": "Mob. No: 8983390126",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.19925938546657562,
#                     "Height": 0.01533882599323988,
#                     "Left": 0.04674968495965004,
#                     "Top": 0.05242994800209999
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.04675997421145439,
#                         "Y": 0.05242994800209999
#                     },
#                     {
#                         "X": 0.24600908160209656,
#                         "Y": 0.05263123661279678
#                     },
#                     {
#                         "X": 0.24599987268447876,
#                         "Y": 0.06776877492666245
#                     },
#                     {
#                         "X": 0.04674968495965004,
#                         "Y": 0.06756545603275299
#                     }
#                 ]
#             },
#             "Id": "9cd6870e-557b-41a6-9969-de8dd84db0fd",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "df3720a9-62ec-4618-bc80-70b9dd9353fe",
#                         "5898b19d-0a8f-483c-a63d-df3ff173f2cf",
#                         "b4eed2f7-973c-42d8-8c62-d8f98b7411e9"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 74.36778259277344,
#             "Text": "411038",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.07475067675113678,
#                     "Height": 0.014681472443044186,
#                     "Left": 0.5851637125015259,
#                     "Top": 0.05277826264500618
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.5851708054542542,
#                         "Y": 0.05277826264500618
#                     },
#                     {
#                         "X": 0.6599143743515015,
#                         "Y": 0.05285376310348511
#                     },
#                     {
#                         "X": 0.6599076390266418,
#                         "Y": 0.06745973229408264
#                     },
#                     {
#                         "X": 0.5851637125015259,
#                         "Y": 0.06738350540399551
#                     }
#                 ]
#             },
#             "Id": "e8b607b5-2a21-4b52-8cf8-9f11875e4a5e",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "a7f11d41-402c-4023-9ff5-bc6ef700d2b9"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 77.39283752441406,
#             "Text": "LOREM IPSUM",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.08860616385936737,
#                     "Height": 0.009697269648313522,
#                     "Left": 0.44210195541381836,
#                     "Top": 0.06514444202184677
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.44210711121559143,
#                         "Y": 0.06514444202184677
#                     },
#                     {
#                         "X": 0.5307081341743469,
#                         "Y": 0.06523468345403671
#                     },
#                     {
#                         "X": 0.5307032465934753,
#                         "Y": 0.07484170794487
#                     },
#                     {
#                         "X": 0.44210195541381836,
#                         "Y": 0.07475090026855469
#                     }
#                 ]
#             },
#             "Id": "b668ca52-933b-4591-b9be-3238ed7f74e7",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "71f38061-e072-44ec-ae97-6e7e4c491ff5",
#                         "c55a9eb4-7e1a-4389-8e44-dc84b15e1691"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.72526550292969,
#             "Text": "Ph: 094233 80390, Timing: 09:00",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.299337774515152,
#                     "Height": 0.018713632598519325,
#                     "Left": 0.5855171084403992,
#                     "Top": 0.07313696295022964
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.5855260491371155,
#                         "Y": 0.07313696295022964
#                     },
#                     {
#                         "X": 0.8848548531532288,
#                         "Y": 0.07344340533018112
#                     },
#                     {
#                         "X": 0.8848479390144348,
#                         "Y": 0.09185059368610382
#                     },
#                     {
#                         "X": 0.5855171084403992,
#                         "Y": 0.09154044836759567
#                     }
#                 ]
#             },
#             "Id": "f45e47a5-1872-42de-af90-6e4588509645",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "7d111719-0092-4a79-96da-1524be2b3b08",
#                         "c9cb7083-2744-4109-b740-280547175be7",
#                         "8aa17027-5222-44fe-a904-31665ba2113f",
#                         "1bbc13b0-8eb8-4e32-9b38-180d3600ba14",
#                         "0578e8a9-9741-48fa-97bf-471fc882b50f"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 94.10716247558594,
#             "Text": "AM - 02:00 PM I Closed: Thursday",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.3008476197719574,
#                     "Height": 0.018741987645626068,
#                     "Left": 0.5847098231315613,
#                     "Top": 0.09367885440587997
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.5847187638282776,
#                         "Y": 0.09367885440587997
#                     },
#                     {
#                         "X": 0.8855574131011963,
#                         "Y": 0.0939909964799881
#                     },
#                     {
#                         "X": 0.8855504393577576,
#                         "Y": 0.11242084205150604
#                     },
#                     {
#                         "X": 0.5847098231315613,
#                         "Y": 0.11210497468709946
#                     }
#                 ]
#             },
#             "Id": "e5587060-4cc6-4d41-8dc7-04926b3a37c1",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "5f30b5da-0f32-44b0-90a8-4eb7b7765e15",
#                         "41cdb5f2-7744-4ad0-9e80-c43867141659",
#                         "ab61a81b-0c48-473b-bbf2-b09d50a77a2f",
#                         "07d0711e-5614-42d5-b192-b740430fcfb6",
#                         "6e67eae0-92da-496f-a14d-3b747135821f",
#                         "8aaecfa1-f1f1-4baa-a27e-7e4da8e90c79",
#                         "c6932c07-a677-4d4c-9448-b3fbc99aa1b5"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.08251953125,
#             "Text": "Date: 27-Apr-2020, 04:37 PM",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.289334774017334,
#                     "Height": 0.0169499721378088,
#                     "Left": 0.6492577791213989,
#                     "Top": 0.19650322198867798
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.649265468120575,
#                         "Y": 0.19650322198867798
#                     },
#                     {
#                         "X": 0.9385925531387329,
#                         "Y": 0.196823388338089
#                     },
#                     {
#                         "X": 0.9385865926742554,
#                         "Y": 0.21345320343971252
#                     },
#                     {
#                         "X": 0.6492577791213989,
#                         "Y": 0.21312980353832245
#                     }
#                 ]
#             },
#             "Id": "ecde0450-b66f-4087-b2c6-2ea25c137ad0",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "687df937-a806-4975-a88a-1229f3305b2d",
#                         "428eb587-6682-44d4-8fec-f794bfea7996",
#                         "e0bb0f7e-bfe1-4664-9cba-eaf9f2089e73",
#                         "77d591d3-edac-44a9-9490-cc72cc30175b"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.67870330810547,
#             "Text": "ID: 266 - DEMO PATIENT (M)",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.2882590591907501,
#                     "Height": 0.017471008002758026,
#                     "Left": 0.04483984783291817,
#                     "Top": 0.21495646238327026
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.04485151916742325,
#                         "Y": 0.21495646238327026
#                     },
#                     {
#                         "X": 0.3330989181995392,
#                         "Y": 0.21527913212776184
#                     },
#                     {
#                         "X": 0.33308902382850647,
#                         "Y": 0.2324274778366089
#                     },
#                     {
#                         "X": 0.04483984783291817,
#                         "Y": 0.23210148513317108
#                     }
#                 ]
#             },
#             "Id": "86ac360d-04bb-4fd8-b89f-731d6dd567cb",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "e5c40535-26e7-46bf-823a-28141958f1bd",
#                         "c1b6db40-7869-48f3-9018-461112b1ba25",
#                         "70d4f3df-d6c4-48a6-9806-e6f506205637",
#                         "a6aa77e7-71d4-4153-9041-bbba2158c16a",
#                         "2c3dbe90-a4fb-4527-849c-8543f5d8c37f",
#                         "4fb91448-f1af-44c4-8788-8ef3c30a11bf"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.3728256225586,
#             "Text": "Address: PUNE",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.13391172885894775,
#                     "Height": 0.014341535046696663,
#                     "Left": 0.044480085372924805,
#                     "Top": 0.2359553724527359
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.04448974132537842,
#                         "Y": 0.2359553724527359
#                     },
#                     {
#                         "X": 0.17839181423187256,
#                         "Y": 0.23610715568065643
#                     },
#                     {
#                         "X": 0.17838284373283386,
#                         "Y": 0.2502969205379486
#                     },
#                     {
#                         "X": 0.044480085372924805,
#                         "Y": 0.2501438558101654
#                     }
#                 ]
#             },
#             "Id": "74e53db9-0344-499f-a314-4d3812c455c9",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "fb83a664-97ed-4eca-860c-56b17e846b60",
#                         "674fad22-b436-43c0-a142-3f48c82f076d"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.487548828125,
#             "Text": "Temp (deg): 36, BP: 120/80 mmHg",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.31673774123191833,
#                     "Height": 0.018112758174538612,
#                     "Left": 0.04451054707169533,
#                     "Top": 0.2562026083469391
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.04452262446284294,
#                         "Y": 0.2562026083469391
#                     },
#                     {
#                         "X": 0.36124828457832336,
#                         "Y": 0.2565659284591675
#                     },
#                     {
#                         "X": 0.3612382411956787,
#                         "Y": 0.27431535720825195
#                     },
#                     {
#                         "X": 0.04451054707169533,
#                         "Y": 0.2739482522010803
#                     }
#                 ]
#             },
#             "Id": "74793fdd-e8ec-49c4-b7bd-764d30ad03bf",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "d777e0a3-5e70-4b4a-8e16-9e138b2a71c7",
#                         "f2da6348-a591-4775-9196-bbd8d2b154f3",
#                         "44a2596d-c128-4d74-b98f-273176dd7d2c",
#                         "d48cdd43-c7a1-4a43-a8af-66a117c5a149",
#                         "47083023-0633-4a16-8d38-43ec1556632f",
#                         "b3ad0e16-7f03-4414-a757-605a7c1d3197"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.6146011352539,
#             "Text": "R",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.01241855788975954,
#                     "Height": 0.013547657057642937,
#                     "Left": 0.04522997885942459,
#                     "Top": 0.29837554693222046
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.04523918777704239,
#                         "Y": 0.29837554693222046
#                     },
#                     {
#                         "X": 0.05764853581786156,
#                         "Y": 0.29839015007019043
#                     },
#                     {
#                         "X": 0.057639386504888535,
#                         "Y": 0.31192320585250854
#                     },
#                     {
#                         "X": 0.04522997885942459,
#                         "Y": 0.3119085133075714
#                     }
#                 ]
#             },
#             "Id": "3bc9046f-3105-4716-9572-9fbb40e9e15f",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "72d3104d-6cac-4f73-9927-0471e049a5c0"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.90862274169922,
#             "Text": "Medicine Name",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.15015390515327454,
#                     "Height": 0.014358549378812313,
#                     "Left": 0.07035447657108307,
#                     "Top": 0.31883397698402405
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.07036399841308594,
#                         "Y": 0.31883397698402405
#                     },
#                     {
#                         "X": 0.2205083817243576,
#                         "Y": 0.31901252269744873
#                     },
#                     {
#                         "X": 0.22049961984157562,
#                         "Y": 0.33319252729415894
#                     },
#                     {
#                         "X": 0.07035447657108307,
#                         "Y": 0.33301252126693726
#                     }
#                 ]
#             },
#             "Id": "aae2ce35-6bab-441f-b3c3-21debb47fd27",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "9bcfa306-2139-4ba2-a02b-a93f8c9312ad",
#                         "5a0006c0-b416-4636-bd63-15b9f3898bc2"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.62017822265625,
#             "Text": "Dosage",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.07346499711275101,
#                     "Height": 0.016305990517139435,
#                     "Left": 0.4200652241706848,
#                     "Top": 0.31935086846351624
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.42007407546043396,
#                         "Y": 0.31935086846351624
#                     },
#                     {
#                         "X": 0.4935302138328552,
#                         "Y": 0.31943821907043457
#                     },
#                     {
#                         "X": 0.4935218095779419,
#                         "Y": 0.3356568515300751
#                     },
#                     {
#                         "X": 0.4200652241706848,
#                         "Y": 0.33556869626045227
#                     }
#                 ]
#             },
#             "Id": "d6c61381-5cf8-418b-8343-75271a772b02",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "23afbbc3-91b1-4a24-92f9-0cc3ec93ed18"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.90946960449219,
#             "Text": "Duration",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.08646336942911148,
#                     "Height": 0.014058111235499382,
#                     "Left": 0.717205286026001,
#                     "Top": 0.3190165162086487
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7172114253044128,
#                         "Y": 0.3190165162086487
#                     },
#                     {
#                         "X": 0.8036686778068542,
#                         "Y": 0.31911927461624146
#                     },
#                     {
#                         "X": 0.8036629557609558,
#                         "Y": 0.3330746293067932
#                     },
#                     {
#                         "X": 0.717205286026001,
#                         "Y": 0.3329710364341736
#                     }
#                 ]
#             },
#             "Id": "8a4f47d5-cffa-470c-b6ed-d27d44af0213",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "52967a09-1665-4883-afc3-815af65bbdf6"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.70726013183594,
#             "Text": "1) TAB. DEMO MEDICINE 1",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.23897860944271088,
#                     "Height": 0.017135566100478172,
#                     "Left": 0.052037402987480164,
#                     "Top": 0.35035184025764465
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.05204882100224495,
#                         "Y": 0.35035184025764465
#                     },
#                     {
#                         "X": 0.29101601243019104,
#                         "Y": 0.35064107179641724
#                     },
#                     {
#                         "X": 0.29100602865219116,
#                         "Y": 0.3674874007701874
#                     },
#                     {
#                         "X": 0.052037402987480164,
#                         "Y": 0.3671954572200775
#                     }
#                 ]
#             },
#             "Id": "5fbe8e1b-13ef-449c-81aa-39f2b49ff8e7",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "5edccf70-fe80-492c-9221-055eca2df4d9",
#                         "176da10f-fbdf-4f91-8476-d972f4b36f95",
#                         "6b173170-5cdf-4e0e-ac58-ac289532fd25",
#                         "81b9524d-1b45-43bd-9648-974c27229bf3",
#                         "382d8f75-0398-49a4-b7fa-83bf77164a6f"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 93.25304412841797,
#             "Text": "1 Morning, 1 Night",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.16531352698802948,
#                     "Height": 0.01694115810096264,
#                     "Left": 0.40206071734428406,
#                     "Top": 0.35059529542922974
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.40206995606422424,
#                         "Y": 0.35059529542922974
#                     },
#                     {
#                         "X": 0.5673742294311523,
#                         "Y": 0.35079535841941833
#                     },
#                     {
#                         "X": 0.5673660039901733,
#                         "Y": 0.3675364553928375
#                     },
#                     {
#                         "X": 0.40206071734428406,
#                         "Y": 0.3673345446586609
#                     }
#                 ]
#             },
#             "Id": "bee4c1d2-760e-4c21-8571-b3bb0186eaae",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "02aa7eff-9886-4a6a-8ab0-5a5a5f786cad",
#                         "b64f7b51-2783-4e14-a91f-a7d964f9a529",
#                         "4143e43f-639f-4e15-ab85-b42539fb34fa",
#                         "fd6eeeb5-bf16-401a-a23a-e8ea04e5748a"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.92386627197266,
#             "Text": "10 Days",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.07126428186893463,
#                     "Height": 0.015716826543211937,
#                     "Left": 0.7120572924613953,
#                     "Top": 0.3515777885913849
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7120642066001892,
#                         "Y": 0.3515777885913849
#                     },
#                     {
#                         "X": 0.7833215594291687,
#                         "Y": 0.35166406631469727
#                     },
#                     {
#                         "X": 0.783315122127533,
#                         "Y": 0.36729463934898376
#                     },
#                     {
#                         "X": 0.7120572924613953,
#                         "Y": 0.3672076165676117
#                     }
#                 ]
#             },
#             "Id": "274f4af7-d81a-42d8-b810-dd0f090bf831",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "009ce95b-3fdb-4496-b64e-c17f3b76dd41",
#                         "b7ea3ba8-e1f8-45c0-9c4c-11af7c5d9ecc"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.28907775878906,
#             "Text": "(Before Food)",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.12035012245178223,
#                     "Height": 0.017017144709825516,
#                     "Left": 0.4076911509037018,
#                     "Top": 0.36942049860954285
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.40770041942596436,
#                         "Y": 0.36942049860954285
#                     },
#                     {
#                         "X": 0.5280412435531616,
#                         "Y": 0.3695676624774933
#                     },
#                     {
#                         "X": 0.5280327200889587,
#                         "Y": 0.38643765449523926
#                     },
#                     {
#                         "X": 0.4076911509037018,
#                         "Y": 0.386289119720459
#                     }
#                 ]
#             },
#             "Id": "03e68db1-a052-43bc-b50c-e4c1a950e256",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "8afc2457-496f-4ba2-a6d5-38dcf0dd0af4",
#                         "c45cb64b-adcd-4397-9635-8a75165086a6"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 98.67279052734375,
#             "Text": "(Tot:20 Tab)",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.1076863706111908,
#                     "Height": 0.017079738900065422,
#                     "Left": 0.7118983268737793,
#                     "Top": 0.36948007345199585
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7119057774543762,
#                         "Y": 0.36948007345199585
#                     },
#                     {
#                         "X": 0.8195846676826477,
#                         "Y": 0.3696117103099823
#                     },
#                     {
#                         "X": 0.8195778727531433,
#                         "Y": 0.3865598142147064
#                     },
#                     {
#                         "X": 0.7118983268737793,
#                         "Y": 0.3864269256591797
#                     }
#                 ]
#             },
#             "Id": "8e12c118-760e-48ea-8fb9-9e9d33135e48",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "93f57189-115f-4d7e-8f9e-156abafcf9b6",
#                         "6ff1f780-db29-498f-9aa2-36f040e76dd7"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.6217269897461,
#             "Text": "2) CAP. DEMO MEDICINE 2",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.24013255536556244,
#                     "Height": 0.017553484067320824,
#                     "Left": 0.051479898393154144,
#                     "Top": 0.399310827255249
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.05149159952998161,
#                         "Y": 0.399310827255249
#                     },
#                     {
#                         "X": 0.291612446308136,
#                         "Y": 0.39960935711860657
#                     },
#                     {
#                         "X": 0.291602224111557,
#                         "Y": 0.4168643057346344
#                     },
#                     {
#                         "X": 0.051479898393154144,
#                         "Y": 0.4165629744529724
#                     }
#                 ]
#             },
#             "Id": "25a85fea-210c-49df-821f-8bb5cdc0095f",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "7dc96fb4-b24a-4d14-b4bf-6ca685d8fc0c",
#                         "73b07512-dc8a-4ab9-bdc1-7366c2ec6b23",
#                         "60b6f210-06fd-4d64-8d7d-0860c0d7c395",
#                         "67974988-9ecf-459c-94e1-82198327b260",
#                         "31348340-868e-4238-a9f2-b96ea7a2836b"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 98.81964111328125,
#             "Text": "1 Morning, 1 Night",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.1655847132205963,
#                     "Height": 0.017169427126646042,
#                     "Left": 0.4019825756549835,
#                     "Top": 0.3998510539531708
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.40199193358421326,
#                         "Y": 0.3998510539531708
#                     },
#                     {
#                         "X": 0.5675672888755798,
#                         "Y": 0.400056928396225
#                     },
#                     {
#                         "X": 0.5675589442253113,
#                         "Y": 0.4170204997062683
#                     },
#                     {
#                         "X": 0.4019825756549835,
#                         "Y": 0.4168127477169037
#                     }
#                 ]
#             },
#             "Id": "3a5a0940-b3c7-419c-8f33-e4b43aa10100",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "ec43eb7c-0d4a-4dfd-b7e0-ed72fde8e91c",
#                         "d1add2df-509a-43ca-82ca-149188438584",
#                         "faab993e-5c59-4241-a585-02de61fece5d",
#                         "b1d69a33-fa55-4cc4-9778-6077078256cc"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.92605590820312,
#             "Text": "10 Days",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.07147859781980515,
#                     "Height": 0.01567395031452179,
#                     "Left": 0.7119621634483337,
#                     "Top": 0.4009406268596649
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7119690775871277,
#                         "Y": 0.4009406268596649
#                     },
#                     {
#                         "X": 0.7834407687187195,
#                         "Y": 0.4010295271873474
#                     },
#                     {
#                         "X": 0.7834343314170837,
#                         "Y": 0.4166145622730255
#                     },
#                     {
#                         "X": 0.7119621634483337,
#                         "Y": 0.4165249168872833
#                     }
#                 ]
#             },
#             "Id": "24ee955d-1c71-432f-a776-e0b00374c60f",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "362016a0-9734-4b0f-ac8e-5a421036a3b2",
#                         "840dba6d-e031-448c-af14-77c09250e524"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 98.70304107666016,
#             "Text": "(Before Food)",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.12037403136491776,
#                     "Height": 0.01678161509335041,
#                     "Left": 0.40788859128952026,
#                     "Top": 0.41883137822151184
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.4078977406024933,
#                         "Y": 0.41883137822151184
#                     },
#                     {
#                         "X": 0.5282626152038574,
#                         "Y": 0.4189825654029846
#                     },
#                     {
#                         "X": 0.5282542109489441,
#                         "Y": 0.4356129765510559
#                     },
#                     {
#                         "X": 0.40788859128952026,
#                         "Y": 0.4354604482650757
#                     }
#                 ]
#             },
#             "Id": "cf009801-5e3d-481a-aa85-1c00042286a7",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "d53c764b-8cfd-4f6f-ade5-41f687de59b9",
#                         "76905715-5e1a-4b65-a594-05f3dccf8bf0"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.07151794433594,
#             "Text": "(Tot:20 Cap)",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.11209496110677719,
#                     "Height": 0.017037224024534225,
#                     "Left": 0.7116068601608276,
#                     "Top": 0.4189895689487457
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7116143107414246,
#                         "Y": 0.4189895689487457
#                     },
#                     {
#                         "X": 0.823701798915863,
#                         "Y": 0.4191303253173828
#                     },
#                     {
#                         "X": 0.8236950635910034,
#                         "Y": 0.43602678179740906
#                     },
#                     {
#                         "X": 0.7116068601608276,
#                         "Y": 0.4358847439289093
#                     }
#                 ]
#             },
#             "Id": "67614576-c85a-40e9-b0aa-c871821f05f8",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "c5676b46-2d54-42ea-8463-08b89540a020",
#                         "28f2edb4-b815-4f71-94e0-fa926513b770"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.63096618652344,
#             "Text": "3) TAB. DEMO MEDICINE 3",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.2399122565984726,
#                     "Height": 0.017365187406539917,
#                     "Left": 0.0516265332698822,
#                     "Top": 0.4488653838634491
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.051638100296258926,
#                         "Y": 0.4488653838634491
#                     },
#                     {
#                         "X": 0.2915387749671936,
#                         "Y": 0.44917163252830505
#                     },
#                     {
#                         "X": 0.29152870178222656,
#                         "Y": 0.466230571269989
#                     },
#                     {
#                         "X": 0.0516265332698822,
#                         "Y": 0.4659215807914734
#                     }
#                 ]
#             },
#             "Id": "94296689-3fe3-4d0f-a322-071bf5ac164b",
#             "Relationships": [
#                 {
#                     "Type": "CHILD",
#                     "Ids": [
#                         "b497a204-a32d-4f83-959c-607317deb179",
#                         "3f6635ca-552e-496d-9653-4a9fbd0aaedd",
#                         "5b6f241b-b918-4b10-8c6b-1e8e5f4e99e0",
#                         "ca8cd6b6-f084-4fc8-a78f-1007ddc85e3f",
#                         "370a9999-85f2-4236-bbd7-1a6be086afe9"
#                     ]
#                 }
#             ]
#         },
#         {
#             "BlockType": "LINE",
#             "Confidence": 99.13304138183594,
#             "Text": "1 Morning, 1 Aft, 1 Eve, 1 Night",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.2809585928916931,
#                     "Height": 0.017497170716524124,
#                     "Left": 0.4023500084877014,
#                     "Top": 0.44896426796913147
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.4023594558238983,
#                         "Y": 0.44896426796913147
#                     },
# ...
#                 "BoundingBox": {
#                     "Width": 0.026255939155817032,
#                     "Height": 0.008700988255441189,
#                     "Left": 0.5779908299446106,
#                     "Top": 0.8439988493919373
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.5779950618743896,
#                         "Y": 0.8439988493919373
#                     },
#                     {
#                         "X": 0.6042467355728149,
#                         "Y": 0.8440393209457397
#                     },
#                     {
#                         "X": 0.6042426228523254,
#                         "Y": 0.852699875831604
#                     },
#                     {
#                         "X": 0.5779908299446106,
#                         "Y": 0.8526592254638672
#                     }
#                 ]
#             },
#             "Id": "1c392fd0-64b1-4bed-807b-0b3e19d47e0b"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 95.21460723876953,
#             "Text": "2020",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.0256634671241045,
#                     "Height": 0.008758512325584888,
#                     "Left": 0.6166746020317078,
#                     "Top": 0.843850314617157
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.616678774356842,
#                         "Y": 0.843850314617157
#                     },
#                     {
#                         "X": 0.6423380970954895,
#                         "Y": 0.8438898324966431
#                     },
#                     {
#                         "X": 0.6423340439796448,
#                         "Y": 0.8526087999343872
#                     },
#                     {
#                         "X": 0.6166746020317078,
#                         "Y": 0.8525691032409668
#                     }
#                 ]
#             },
#             "Id": "19f7d1c3-5f29-4bbc-ae2f-215d37f6d508"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 96.4339828491211,
#             "Text": "2020",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.026176415383815765,
#                     "Height": 0.008873344399034977,
#                     "Left": 0.6547607183456421,
#                     "Top": 0.8437438607215881
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.6547647714614868,
#                         "Y": 0.8437438607215881
#                     },
#                     {
#                         "X": 0.6809371113777161,
#                         "Y": 0.8437842130661011
#                     },
#                     {
#                         "X": 0.6809331178665161,
#                         "Y": 0.8526172041893005
#                     },
#                     {
#                         "X": 0.6547607183456421,
#                         "Y": 0.852576732635498
#                     }
#                 ]
#             },
#             "Id": "ffd2f1ce-5794-4d57-b73c-0455c01df341"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 97.26347351074219,
#             "Text": "2020",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.025964150205254555,
#                     "Height": 0.008850209414958954,
#                     "Left": 0.6932547092437744,
#                     "Top": 0.8438302278518677
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.6932586431503296,
#                         "Y": 0.8438302278518677
#                     },
#                     {
#                         "X": 0.7192188501358032,
#                         "Y": 0.843870222568512
#                     },
#                     {
#                         "X": 0.7192149758338928,
#                         "Y": 0.8526804447174072
#                     },
#                     {
#                         "X": 0.6932547092437744,
#                         "Y": 0.8526402711868286
#                     }
#                 ]
#             },
#             "Id": "b6235b62-b6ca-4615-9ba2-8417c232f9cb"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 85.81494903564453,
#             "Text": "2020",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.025687742978334427,
#                     "Height": 0.00869807880371809,
#                     "Left": 0.7317021489143372,
#                     "Top": 0.8438645005226135
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7317058444023132,
#                         "Y": 0.8438645005226135
#                     },
#                     {
#                         "X": 0.7573898434638977,
#                         "Y": 0.8439040780067444
#                     },
#                     {
#                         "X": 0.7573862075805664,
#                         "Y": 0.8525626063346863
#                     },
#                     {
#                         "X": 0.7317021489143372,
#                         "Y": 0.8525228500366211
#                     }
#                 ]
#             },
#             "Id": "30879fed-3baf-4cc0-8a3f-93e223a82b22"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.76123809814453,
#             "Text": "Date",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.028410183265805244,
#                     "Height": 0.009793194942176342,
#                     "Left": 0.2372070997953415,
#                     "Top": 0.8587813377380371
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.23721304535865784,
#                         "Y": 0.8587813377380371
#                     },
#                     {
#                         "X": 0.2656172811985016,
#                         "Y": 0.8588253855705261
#                     },
#                     {
#                         "X": 0.2656114101409912,
#                         "Y": 0.8685745000839233
#                     },
#                     {
#                         "X": 0.2372070997953415,
#                         "Y": 0.8685302734375
#                     }
#                 ]
#             },
#             "Id": "192c583f-3184-42bb-9b0e-0df8638cfa3e"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.74893951416016,
#             "Text": "Date",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.02886887826025486,
#                     "Height": 0.010209438391029835,
#                     "Left": 0.6123372316360474,
#                     "Top": 0.858592689037323
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.6123420596122742,
#                         "Y": 0.858592689037323
#                     },
#                     {
#                         "X": 0.6412060856819153,
#                         "Y": 0.8586374521255493
#                     },
#                     {
#                         "X": 0.641201376914978,
#                         "Y": 0.8688021302223206
#                     },
#                     {
#                         "X": 0.6123372316360474,
#                         "Y": 0.8687571287155151
#                     }
#                 ]
#             },
#             "Id": "2cf4878a-1c09-4cb3-87b0-2d206121fc25"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.40796661376953,
#             "Text": "Signature",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.13823217153549194,
#                     "Height": 0.04465247318148613,
#                     "Left": 0.8051303029060364,
#                     "Top": 0.8960381150245667
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.8051483631134033,
#                         "Y": 0.8960381150245667
#                     },
#                     {
#                         "X": 0.9433624744415283,
#                         "Y": 0.8962559700012207
#                     },
#                     {
#                         "X": 0.9433466196060181,
#                         "Y": 0.9406905770301819
#                     },
#                     {
#                         "X": 0.8051303029060364,
#                         "Y": 0.9404686093330383
#                     }
#                 ]
#             },
#             "Id": "9b9c0d05-f16a-4179-bee2-58c84b874b66"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.34489440917969,
#             "Text": "Dr.",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.02932998538017273,
#                     "Height": 0.01328950934112072,
#                     "Left": 0.7726696133613586,
#                     "Top": 0.9411457777023315
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7726751565933228,
#                         "Y": 0.9411457777023315
#                     },
#                     {
#                         "X": 0.8019996285438538,
#                         "Y": 0.9411928653717041
#                     },
#                     {
#                         "X": 0.8019942045211792,
#                         "Y": 0.9544352889060974
#                     },
#                     {
#                         "X": 0.7726696133613586,
#                         "Y": 0.954387903213501
#                     }
#                 ]
#             },
#             "Id": "60624389-0272-4dd4-a237-77b591ab10ae"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.5391845703125,
#             "Text": "Onkar",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.06039529666304588,
#                     "Height": 0.013624357059597969,
#                     "Left": 0.8086095452308655,
#                     "Top": 0.9408877491950989
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.8086150288581848,
#                         "Y": 0.9408877491950989
#                     },
#                     {
#                         "X": 0.8690048456192017,
#                         "Y": 0.9409847259521484
#                     },
#                     {
#                         "X": 0.8689996600151062,
#                         "Y": 0.9545121192932129
#                     },
#                     {
#                         "X": 0.8086095452308655,
#                         "Y": 0.9544145464897156
#                     }
#                 ]
#             },
#             "Id": "d92eda16-6520-4aec-818f-eca7eddb1a61"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.68726348876953,
#             "Text": "Bhave",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.060767367482185364,
#                     "Height": 0.013613197952508926,
#                     "Left": 0.874405026435852,
#                     "Top": 0.9407666325569153
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.8744102120399475,
#                         "Y": 0.9407666325569153
#                     },
#                     {
#                         "X": 0.935172438621521,
#                         "Y": 0.9408642053604126
#                     },
#                     {
#                         "X": 0.9351675510406494,
#                         "Y": 0.9543797969818115
#                     },
#                     {
#                         "X": 0.874405026435852,
#                         "Y": 0.9542816877365112
#                     }
#                 ]
#             },
#             "Id": "0e6db82b-eaef-44b9-bd2d-1a8c923a403f"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 98.43132781982422,
#             "Text": "M.B.B.S.,",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.08725420385599136,
#                     "Height": 0.01616186834871769,
#                     "Left": 0.742429792881012,
#                     "Top": 0.9612860679626465
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.7424367070198059,
#                         "Y": 0.9612860679626465
#                     },
#                     {
#                         "X": 0.8296840190887451,
#                         "Y": 0.9614274501800537
#                     },
#                     {
#                         "X": 0.8296776413917542,
#                         "Y": 0.9774479866027832
#                     },
#                     {
#                         "X": 0.742429792881012,
#                         "Y": 0.9773057103157043
#                     }
#                 ]
#             },
#             "Id": "bde972da-2433-4e3a-b350-d2fff3b046b1"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.21112060546875,
#             "Text": "M.D.,",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.04922390729188919,
#                     "Height": 0.015529892407357693,
#                     "Left": 0.8371063470840454,
#                     "Top": 0.9614571928977966
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.8371124863624573,
#                         "Y": 0.9614571928977966
#                     },
#                     {
#                         "X": 0.886330246925354,
#                         "Y": 0.9615368843078613
#                     },
#                     {
#                         "X": 0.886324405670166,
#                         "Y": 0.9769870638847351
#                     },
#                     {
#                         "X": 0.8371063470840454,
#                         "Y": 0.9769068360328674
#                     }
#                 ]
#             },
#             "Id": "409b0e1c-8af4-49f8-b0b4-044272b94ba1"
#         },
#         {
#             "BlockType": "WORD",
#             "Confidence": 99.30783081054688,
#             "Text": "M.S.",
#             "TextType": "PRINTED",
#             "Geometry": {
#                 "BoundingBox": {
#                     "Width": 0.04124581068754196,
#                     "Height": 0.014079331420361996,
#                     "Left": 0.8937814831733704,
#                     "Top": 0.9614023566246033
#                 },
#                 "Polygon": [
#                     {
#                         "X": 0.8937867879867554,
#                         "Y": 0.9614023566246033
#                     },
#                     {
#                         "X": 0.9350273013114929,
#                         "Y": 0.9614691734313965
#                     },
#                     {
#                         "X": 0.9350222945213318,
#                         "Y": 0.9754816889762878
#                     },
#                     {
#                         "X": 0.8937814831733704,
#                         "Y": 0.975414514541626
#                     }
#                 ]
#             },
#             "Id": "1d335a1e-febc-4f48-b6f9-7f5f4d8229c1"
#         }
#     ],
#     "DetectDocumentTextModelVersion": "1.0",
#     "ResponseMetadata": {
#         "RequestId": "5ca729c1-39eb-47a7-81a8-c7d3fa9decb5",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "x-amzn-requestid": "5ca729c1-39eb-47a7-81a8-c7d3fa9decb5",
#             "content-type": "application/x-amz-json-1.1",
#             "content-length": "139135",
#             "date": "Sat, 29 Mar 2025 21:52:54 GMT"
#         },
#         "RetryAttempts": 0
#     }
# }

# %%
# Extract the text from the response
extracted_text = ''
for item in response['Blocks']:
    if item['BlockType'] == 'LINE':
        extracted_text += item['Text'] + '\n'
print(extracted_text)
# Out:
# Dr. Onkar Bhave
# Care Clinic
# M.B.B.S., M.D., M.S. I Reg. No: 270988 I
# Near Axis Bank, Kothrud, Pune -
# Mob. No: 8983390126
# 411038
# LOREM IPSUM
# Ph: 094233 80390, Timing: 09:00
# AM - 02:00 PM I Closed: Thursday
# Date: 27-Apr-2020, 04:37 PM
# ID: 266 - DEMO PATIENT (M)
# Address: PUNE
# Temp (deg): 36, BP: 120/80 mmHg
# R
# Medicine Name
# Dosage
# Duration
# 1) TAB. DEMO MEDICINE 1
# 1 Morning, 1 Night
# 10 Days
# (Before Food)
# (Tot:20 Tab)
# 2) CAP. DEMO MEDICINE 2
# 1 Morning, 1 Night
# 10 Days
# (Before Food)
# (Tot:20 Cap)
# 3) TAB. DEMO MEDICINE 3
# 1 Morning, 1 Aft, 1 Eve, 1 Night
# 10 Days
# (After Food)
# (Tot:40 Tab)
# 4) TAB. DEMO MEDICINE 4
# 1/2 Morning, 1/2 Night
# 10 Days
# (After Food)
# (Tot:10 Tab)
# Advice Given:
# * AVOID OILY AND SPICY FOOD
# Follow Up: 12-05-2020
# Charts
# 40
# 17
# 140
# 120
# 129
# 120
# 35
# 120
# 30
# 100
# 90
# as
# .
# 80
# 20
# 60
# 10
# 40
# 20
# 0
# 0
# 23-02- 09-03- 22-01- 05-04- 19-04- 03-05- 17-05-
# 23-02- 08-03- 22-03- 05-44 19.44 03-45 17-05
# 2020 2020 2020 2020 2020 2020 2020
# 2820 2520 2020 2020 2020 2020 2020
# Date
# Date
# Signature
# Dr. Onkar Bhave
# M.B.B.S., M.D., M.S.

# %%
response = textract.analyze_document(
    Document={'Bytes': image_bytes},
    FeatureTypes=['TABLES']
)

# %%
def get_table_data(response):
    blocks = response['Blocks']
    blocks_map = {}
    table_blocks = []
    
    # Map block IDs to blocks
    for block in blocks:
        blocks_map[block['Id']] = block
        if block['BlockType'] == "TABLE":
            table_blocks.append(block)
    
    if len(table_blocks) <= 0:
        return []  # Return empty list if no tables found
    
    # List to store all tables
    all_tables = []
    
    # Process each table
    for table_index, table in enumerate(table_blocks):
        # Get rows and columns
        rows = {}
        for relationship in table['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    cell = blocks_map[child_id]
                    if cell['BlockType'] == 'CELL':
                        row_index = cell['RowIndex']
                        col_index = cell['ColumnIndex']
                        if row_index not in rows:
                            rows[row_index] = {}
                        
                        # Get text from cell
                        text = ""
                        if 'Relationships' in cell:
                            for rel in cell['Relationships']:
                                if rel['Type'] == 'CHILD':
                                    for word_id in rel['Ids']:
                                        word = blocks_map[word_id]
                                        if word['BlockType'] == 'WORD':
                                            text += word['Text'] + ' '
                        
                        rows[row_index][col_index] = text.strip()
        
        # Convert to list of lists format
        table_data = []
        for row_index in sorted(rows.keys()):
            row_data = []
            for col_index in sorted(rows[row_index].keys()):
                row_data.append(rows[row_index][col_index])
            table_data.append(row_data)
        
        all_tables.append(table_data)
    
    return all_tables

# Call the function with the response
tables = get_table_data(response)

# Now you can use the returned data however you want
for i, table in enumerate(tables):
    print(f"Table {i + 1}:")
    for row in table:
        print(",".join(row))
# Out:
# Table 1:
# Medicine Name,Dosage,Duration
# 1) TAB. DEMO MEDICINE 1,1 Morning, 1 Night (Before Food),10 Days (Tot:20 Tab)
# 2) CAP. DEMO MEDICINE 2,1 Morning, 1 Night (Before Food),10 Days (Tot:20 Cap)
# 3) TAB. DEMO MEDICINE 3,1 Morning, 1 Aft, 1 Eve, 1 Night (After Food),10 Days (Tot:40 Tab)
# 4) TAB. DEMO MEDICINE 4,1/2 Morning, 1/2 Night (After Food),10 Days (Tot:10 Tab)

# %%
def get_table_data_as_string(response):
    blocks = response['Blocks']
    blocks_map = {}
    table_blocks = []
    
    # Map block IDs to blocks
    for block in blocks:
        blocks_map[block['Id']] = block
        if block['BlockType'] == "TABLE":
            table_blocks.append(block)
    
    if len(table_blocks) <= 0:
        return "No tables found"
    
    # String to store all table data
    result_string = ""
    
    # Process each table
    for table_index, table in enumerate(table_blocks):
        result_string += f"Table {table_index + 1}:\n"
        
        # Get rows and columns
        rows = {}
        for relationship in table['Relationships']:
            if relationship['Type'] == 'CHILD':
                for child_id in relationship['Ids']:
                    cell = blocks_map[child_id]
                    if cell['BlockType'] == 'CELL':
                        row_index = cell['RowIndex']
                        col_index = cell['ColumnIndex']
                        if row_index not in rows:
                            rows[row_index] = {}
                        
                        # Get text from cell
                        text = ""
                        if 'Relationships' in cell:
                            for rel in cell['Relationships']:
                                if rel['Type'] == 'CHILD':
                                    for word_id in rel['Ids']:
                                        word = blocks_map[word_id]
                                        if word['BlockType'] == 'WORD':
                                            text += word['Text'] + ' '
                        
                        rows[row_index][col_index] = text.strip()
        
        # Convert to CSV-like string
        for row_index in sorted(rows.keys()):
            csv_row = ""
            for col_index in sorted(rows[row_index].keys()):
                csv_row += f"{rows[row_index][col_index]},"
            result_string += csv_row + "\n"
        
        # Add a blank line between tables if there are multiple
        if table_index < len(table_blocks) - 1:
            result_string += "\n"
    
    return result_string

# Call the function with the response
table_string = get_table_data_as_string(response)

# Now you can use the returned string however you want
print(table_string)
# Out:
# Table 1:
# Medicine Name,Dosage,Duration,
# 1) TAB. DEMO MEDICINE 1,1 Morning, 1 Night (Before Food),10 Days (Tot:20 Tab),
# 2) CAP. DEMO MEDICINE 2,1 Morning, 1 Night (Before Food),10 Days (Tot:20 Cap),
# 3) TAB. DEMO MEDICINE 3,1 Morning, 1 Aft, 1 Eve, 1 Night (After Food),10 Days (Tot:40 Tab),
# 4) TAB. DEMO MEDICINE 4,1/2 Morning, 1/2 Night (After Food),10 Days (Tot:10 Tab),

# %%
table_string
# Out:
# 'Table 1:\nMedicine Name,Dosage,Duration,\n1) TAB. DEMO MEDICINE 1,1 Morning, 1 Night (Before Food),10 Days (Tot:20 Tab),\n2) CAP. DEMO MEDICINE 2,1 Morning, 1 Night (Before Food),10 Days (Tot:20 Cap),\n3) TAB. DEMO MEDICINE 3,1 Morning, 1 Aft, 1 Eve, 1 Night (After Food),10 Days (Tot:40 Tab),\n4) TAB. DEMO MEDICINE 4,1/2 Morning, 1/2 Night (After Food),10 Days (Tot:10 Tab),\n'

# %%
sys_prompt = """
You are a medical prescription assistant. You have been given a text extracted from a prescription.
It might be in a raw format or in a table format. Your task is to extract the information and give it in JSON.
GIVE THE OUTPUT STRICTLY IN A JSON FORMAT. DO NOT INCLUDE ANY OTHER TEXT OR EXPLANATION.
Output format:
                [
                    {
                        "medicine": "Medication A",
                        "frequency": "1-0-1",
                        "duration": "7 days",
                        "special_instructions": "Before food"
                    },
                    {
                        "medicine": "Medication B",
                        "frequency": "1-0-0",
                        "duration": "7 days",
                        "special_instructions": "After Food"
                    }
                ]
                So frequency is the time of day when the medicine should be taken, it may be mentioned as Morning, Night, Aft, Eve etc. or may be mentioned as 1-0-1, 0-1-0 etc. If it is mentioned as day and night, you should put it as 1-0-1. Just night means 0-0-1.
                Duration is the number of days for which the medicine should be taken. It may be mentioned as 7 days, 10 days etc.
                Special instructions are any special instructions given by the doctor. If there are no special instructions, please mention it as None.
"""

# %%
bot_response = llm.invoke([
    SystemMessage(content=sys_prompt),
    HumanMessage(content=table_string),
])

print(bot_response.content)
# Out:
# [
#     {
#         "medicine": "TAB. DEMO MEDICINE 1",
#         "frequency": "1-0-1",
#         "duration": "10 days",
#         "special_instructions": "Before Food"
#     },
#     {
#         "medicine": "CAP. DEMO MEDICINE 2",
#         "frequency": "1-0-1",
#         "duration": "10 days",
#         "special_instructions": "Before Food"
#     },
#     {
#         "medicine": "TAB. DEMO MEDICINE 3",
#         "frequency": "1-1-1-1",
#         "duration": "10 days",
#         "special_instructions": "After Food"
#     },
#     {
#         "medicine": "TAB. DEMO MEDICINE 4",
#         "frequency": "0.5-0-0-0.5",
#         "duration": "10 days",
#         "special_instructions": "After Food"
#     }
# ]
